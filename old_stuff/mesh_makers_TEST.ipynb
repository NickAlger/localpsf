# %%
import numpy as np
import fenics
from mesh_makers import circle_mesh
import matplotlib.pyplot as plt

# %%
mesh_center = np.array([0.5,0.5])
mesh_radius = 0.5
mesh_h1 = 1e-1
mesh_h2 = 5e-2

# %%
mesh1 = circle_mesh(mesh_center, mesh_radius, 1./mesh_h1)
mesh2 = circle_mesh(mesh_center, mesh_radius, 1./mesh_h2)
fenics.plot(mesh1)
plt.figure()
fenics.plot(mesh2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f930c6c91f0>,
#  <matplotlib.lines.Line2D at 0x7f930c6c9580>]
